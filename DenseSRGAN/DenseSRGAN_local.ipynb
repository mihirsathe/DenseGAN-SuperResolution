# %%
# Local paths
dir_pfx = './'
data_dir = dir_pfx + '../../data/Vehicules1024/'
# Add the local_modules directory to the set of paths
# Python uses to look for imports.
import sys
sys.path.append(dir_pfx)
sys.path.append('../')

# %%
#!pip3 install -q git+https://www.github.com/keras-team/keras-contrib.git
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from importlib import reload
import utils
# Out:
# Using TensorFlow backend.

# %%
reload(utils)
# Out:
# <module 'utils' from '../utils.py'>

# %%
#num_images = 3
#files = utils.scan_dataset(data_dir, num_images) #TODO: 50
#training_set, testing_set = utils.create_subsets(files, data_dir, use_validation=False)
#im_hr, im_lr, batch_idx = utils.load_data(0, training_set, data_dir, True, len(training_set))
vehicles_dir = dir_pfx + '../../data/vehicle_patches_64/'
#im_hr, im_lr = utils.load_data_vehicles(vehicles_dir, 1, img_spec=2021)
im_hr, im_lr = utils.load_data_vehicles(vehicles_dir, 17)
# Out:
# using 17 images
# 17

# %%
ix = 10
normalized_around_zero = True

if normalized_around_zero:
    plt.figure().suptitle('RGB+Infra', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(utils.un_normalize(im_hr[ix,:,:,:]))
    plt.subplot(1,2,2)
    plt.imshow(utils.un_normalize(im_lr[ix,:,:,:]))

    plt.figure().suptitle('RGB', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(utils.un_normalize(im_hr[ix,:,:,0:3]))
    plt.subplot(1,2,2)
    plt.imshow(utils.un_normalize(im_lr[ix,:,:,0:3]))
else:
    plt.figure().suptitle('RGB+Infra', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(im_hr[ix,:,:,:])
    plt.subplot(1,2,2)
    plt.imshow(im_lr[ix,:,:,:])

    plt.figure().suptitle('RGB', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(im_hr[ix,:,:,0:3])
    plt.subplot(1,2,2)
    plt.imshow(im_lr[ix,:,:,0:3])

# %%
# Prototype the Dense SR GAN
#from importlib import reload
reload(DenseSRGAN)
# Out:
# <module 'DenseSRGAN' from '/home/jupyter/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py'>

# %%
import DenseSRGAN
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr[0:17,:,:,:],im_lr[0:17,:,:,:],num_gpus=[4,5,6,7],dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=[6],dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=4,dropout_rate=0.3,weights_path='weights/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-dd733fa033f9> in <module>
#       1 import DenseSRGAN
#       2 #gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr[0:17,:,:,:],im_lr[0:17,:,:,:],num_gpus=[4,5,6,7],dropout_rate=0.3)
# ----> 3 gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=[6],dropout_rate=0.3)
#       4 #gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=4,dropout_rate=0.3,weights_path='weights/')
#
# ~/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py in __init__(self, dir_pfx, datahr, datalr, num_gpus, hr_img_size, down_factor, num_layers_in_blk, num_dense_blks, growth_rate, num_filters, dropout_rate, weight_decay, weights_path)
#      72
#      73     # Initialize
# ---> 74     self.build_models()
#      75
#      76     # TODO: Things (Not in order of importance)
#
# ~/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py in build_models(self)
#     218     # Create the model
#     219     if self.num_gpus is not None:
# --> 220       self.disc_model = multi_gpu_model(self.disc, gpus=self.num_gpus)
#     221     else:
#     222       self.disc_model = self.disc
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/training_utils.py in multi_gpu_model(model, gpus)
#     114             raise ValueError('For multi-gpu usage to be effective, '
#     115                              'call `multi_gpu_model` with `len(gpus) >= 2`. '
# --> 116                              'Received: `gpus=%s`' % gpus)
#     117         num_gpus = len(gpus)
#     118         target_gpu_ids = gpus
#
# ValueError: For multi-gpu usage to be effective, call `multi_gpu_model` with `len(gpus) >= 2`. Received: `gpus=[6]`

# %%
#gan.dropout_rate = .5
gan.train(epochs=3000,verbose=False,bench_idx=12,batch_size=4,save_interval=50,view_interval=20)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 0... Time: 0:01:51.815077
# 0:0: [D loss_hr: 0.243720, acc_hr: 0.546875, loss_gen: 0.330072, acc_gen: 0.171875]  [A loss: 0.712722, acc: 0.500000]
# Saving weights at epoch 0
# Saving weights at epoch 10
# Finished Epoch 20... Time: 0:00:00.217641
# 20:0: [D loss_hr: 0.010091, acc_hr: 1.000000, loss_gen: 0.004519, acc_gen: 1.000000]  [A loss: 2.758024, acc: 0.000000]
# Saving weights at epoch 20
# Saving weights at epoch 30
# Finished Epoch 40... Time: 0:00:00.213446
# 40:0: [D loss_hr: 0.004849, acc_hr: 1.000000, loss_gen: 0.024864, acc_gen: 0.937500]  [A loss: 3.752512, acc: 0.000000]
# Saving weights at epoch 40
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 50
# Finished Epoch 60... Time: 0:00:00.216587
# 60:0: [D loss_hr: 0.000360, acc_hr: 1.000000, loss_gen: 0.000892, acc_gen: 1.000000]  [A loss: 3.519883, acc: 0.000000]
# Saving weights at epoch 60
# Saving weights at epoch 70
# Finished Epoch 80... Time: 0:00:00.220517
# 80:0: [D loss_hr: 0.000280, acc_hr: 1.000000, loss_gen: 0.000356, acc_gen: 1.000000]  [A loss: 3.702004, acc: 0.000000]
# Saving weights at epoch 80
# Saving weights at epoch 90
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 100... Time: 0:00:00.215324
# 100:0: [D loss_hr: 0.000095, acc_hr: 1.000000, loss_gen: 0.000032, acc_gen: 1.000000]  [A loss: 4.647979, acc: 0.000000]
# Saving weights at epoch 100
# Saving weights at epoch 110
# Finished Epoch 120... Time: 0:00:00.218565
# 120:0: [D loss_hr: 0.000082, acc_hr: 1.000000, loss_gen: 0.000131, acc_gen: 1.000000]  [A loss: 4.746917, acc: 0.000000]
# Saving weights at epoch 120
# Saving weights at epoch 130
# Finished Epoch 140... Time: 0:00:00.216501
# 140:0: [D loss_hr: 0.000102, acc_hr: 1.000000, loss_gen: 0.000098, acc_gen: 1.000000]  [A loss: 3.425538, acc: 0.015625]
# Saving weights at epoch 140
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 150
# Finished Epoch 160... Time: 0:00:00.207913
# 160:0: [D loss_hr: 0.000036, acc_hr: 1.000000, loss_gen: 0.000005, acc_gen: 1.000000]  [A loss: 4.458154, acc: 0.000000]
# Saving weights at epoch 160
# Saving weights at epoch 170
# Finished Epoch 180... Time: 0:00:00.221848
# 180:0: [D loss_hr: 0.000059, acc_hr: 1.000000, loss_gen: 0.000004, acc_gen: 1.000000]  [A loss: 4.997660, acc: 0.000000]
# Saving weights at epoch 180
# Saving weights at epoch 190
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 200... Time: 0:00:00.206751
# 200:0: [D loss_hr: 0.000023, acc_hr: 1.000000, loss_gen: 0.000067, acc_gen: 1.000000]  [A loss: 0.658817, acc: 0.703125]
# Saving weights at epoch 200
# Saving weights at epoch 210
# Finished Epoch 220... Time: 0:00:00.213698
# 220:0: [D loss_hr: 0.000031, acc_hr: 1.000000, loss_gen: 0.000178, acc_gen: 1.000000]  [A loss: 4.146418, acc: 0.000000]
# Saving weights at epoch 220
# Saving weights at epoch 230
# Finished Epoch 240... Time: 0:00:00.215744
# 240:0: [D loss_hr: 0.000012, acc_hr: 1.000000, loss_gen: 0.000007, acc_gen: 1.000000]  [A loss: 5.558061, acc: 0.000000]
# Saving weights at epoch 240
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 250
# Finished Epoch 260... Time: 0:00:00.208000
# 260:0: [D loss_hr: 0.000006, acc_hr: 1.000000, loss_gen: 0.000004, acc_gen: 1.000000]  [A loss: 6.984661, acc: 0.000000]
# Saving weights at epoch 260
# Saving weights at epoch 270
# Finished Epoch 280... Time: 0:00:00.217260
# 280:0: [D loss_hr: 0.000003, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 7.834348, acc: 0.000000]
# Saving weights at epoch 280
# Saving weights at epoch 290
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 300... Time: 0:00:00.210645
# 300:0: [D loss_hr: 0.000365, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 7.369997, acc: 0.000000]
# Saving weights at epoch 300
# Saving weights at epoch 310
# Finished Epoch 320... Time: 0:00:00.210497
# 320:0: [D loss_hr: 0.000003, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 6.483728, acc: 0.000000]
# Saving weights at epoch 320
# Saving weights at epoch 330
# Finished Epoch 340... Time: 0:00:00.210852
# 340:0: [D loss_hr: 0.000010, acc_hr: 1.000000, loss_gen: 0.000013, acc_gen: 1.000000]  [A loss: 7.137322, acc: 0.000000]
# Saving weights at epoch 340
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 350
# Finished Epoch 360... Time: 0:00:00.213002
# 360:0: [D loss_hr: 0.000002, acc_hr: 1.000000, loss_gen: 0.000009, acc_gen: 1.000000]  [A loss: 6.962485, acc: 0.000000]
# Saving weights at epoch 360
# Saving weights at epoch 370
# Finished Epoch 380... Time: 0:00:00.213471
# 380:0: [D loss_hr: 0.000003, acc_hr: 1.000000, loss_gen: 0.000004, acc_gen: 1.000000]  [A loss: 6.345232, acc: 0.000000]
# Saving weights at epoch 380
# Saving weights at epoch 390
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 400... Time: 0:00:00.213478
# 400:0: [D loss_hr: 0.000006, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 7.077798, acc: 0.000000]
# Saving weights at epoch 400
# Saving weights at epoch 410
# Finished Epoch 420... Time: 0:00:00.208472
# 420:0: [D loss_hr: 0.000002, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 6.498584, acc: 0.015625]
# Saving weights at epoch 420
# Saving weights at epoch 430
# Finished Epoch 440... Time: 0:00:00.213963
# 440:0: [D loss_hr: 0.000011, acc_hr: 1.000000, loss_gen: 0.000014, acc_gen: 1.000000]  [A loss: 7.286254, acc: 0.000000]
# Saving weights at epoch 440
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 450
# Finished Epoch 460... Time: 0:00:00.218691
# 460:0: [D loss_hr: 0.002544, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.184050, acc: 0.000000]
# Saving weights at epoch 460
# Saving weights at epoch 470
# Finished Epoch 480... Time: 0:00:00.213665
# 480:0: [D loss_hr: 0.000020, acc_hr: 1.000000, loss_gen: 0.000002, acc_gen: 1.000000]  [A loss: 6.949996, acc: 0.000000]
# Saving weights at epoch 480
# Saving weights at epoch 490
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 500... Time: 0:00:00.216333
# 500:0: [D loss_hr: 0.000025, acc_hr: 1.000000, loss_gen: 0.000005, acc_gen: 1.000000]  [A loss: 7.103082, acc: 0.000000]
# Saving weights at epoch 500
# Saving weights at epoch 510
# Finished Epoch 520... Time: 0:00:00.216969
# 520:0: [D loss_hr: 0.000002, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 5.932501, acc: 0.000000]
# Saving weights at epoch 520
# Saving weights at epoch 530
# Finished Epoch 540... Time: 0:00:00.207420
# 540:0: [D loss_hr: 0.000001, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.245702, acc: 0.000000]
# Saving weights at epoch 540
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 550
# Finished Epoch 560... Time: 0:00:00.216226
# 560:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 7.593380, acc: 0.000000]
# Saving weights at epoch 560
# Saving weights at epoch 570
# Finished Epoch 580... Time: 0:00:00.212447
# 580:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.592431, acc: 0.000000]
# Saving weights at epoch 580
# Saving weights at epoch 590
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 600... Time: 0:00:00.222281
# 600:0: [D loss_hr: 0.000005, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 9.965552, acc: 0.000000]
# Saving weights at epoch 600
# Saving weights at epoch 610
# Finished Epoch 620... Time: 0:00:00.211253
# 620:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.944574, acc: 0.000000]
# Saving weights at epoch 620
# Saving weights at epoch 630
# Finished Epoch 640... Time: 0:00:00.213368
# 640:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.398407, acc: 0.015625]
# Saving weights at epoch 640
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 650
# Finished Epoch 660... Time: 0:00:00.218831
# 660:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000003, acc_gen: 1.000000]  [A loss: 8.692444, acc: 0.000000]
# Saving weights at epoch 660
# Saving weights at epoch 670
# Finished Epoch 680... Time: 0:00:00.212619
# 680:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.428182, acc: 0.000000]
# Saving weights at epoch 680
# Saving weights at epoch 690
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 700... Time: 0:00:00.210954
# 700:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 9.511028, acc: 0.000000]
# Saving weights at epoch 700
# Saving weights at epoch 710
# Finished Epoch 720... Time: 0:00:00.214986
# 720:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 9.308618, acc: 0.000000]
# Saving weights at epoch 720
# Saving weights at epoch 730
# Finished Epoch 740... Time: 0:00:00.214253
# 740:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.976822, acc: 0.000000]
# Saving weights at epoch 740
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 750
# Finished Epoch 760... Time: 0:00:00.212880
# 760:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.515244, acc: 0.000000]
# Saving weights at epoch 760
# Saving weights at epoch 770
# Finished Epoch 780... Time: 0:00:00.233760
# 780:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.004805, acc_gen: 1.000000]  [A loss: 11.286659, acc: 0.000000]
# Saving weights at epoch 780
# Saving weights at epoch 790
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 800... Time: 0:00:00.206269
# 800:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 10.524993, acc: 0.000000]
# Saving weights at epoch 800
# Saving weights at epoch 810
# Finished Epoch 820... Time: 0:00:00.214366
# 820:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 11.529190, acc: 0.000000]
# Saving weights at epoch 820
# Saving weights at epoch 830
# Finished Epoch 840... Time: 0:00:00.216851
# 840:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 11.082848, acc: 0.000000]
# Saving weights at epoch 840
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 850
# Finished Epoch 860... Time: 0:00:00.211157
# 860:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.467554, acc: 0.000000]
# Saving weights at epoch 860
# Saving weights at epoch 870
# Finished Epoch 880... Time: 0:00:00.216002
# 880:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.286110, acc: 0.000000]
# Saving weights at epoch 880
# Saving weights at epoch 890
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 900... Time: 0:00:00.218505
# 900:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 9.734023, acc: 0.000000]
# Saving weights at epoch 900
# Saving weights at epoch 910
# Finished Epoch 920... Time: 0:00:00.219972
# 920:0: [D loss_hr: 0.000007, acc_hr: 1.000000, loss_gen: 0.000002, acc_gen: 1.000000]  [A loss: 13.554005, acc: 0.000000]
# Saving weights at epoch 920
# Saving weights at epoch 930
# Finished Epoch 940... Time: 0:00:00.214078
# 940:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 11.950068, acc: 0.000000]
# Saving weights at epoch 940
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 950
# Finished Epoch 960... Time: 0:00:00.220756
# 960:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 5.580403, acc: 0.359375]
# Saving weights at epoch 960
# Saving weights at epoch 970
# Finished Epoch 980... Time: 0:00:00.210211
# 980:0: [D loss_hr: 0.000308, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.671493, acc: 0.000000]
# Saving weights at epoch 980
# Saving weights at epoch 990
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1000... Time: 0:00:00.221969
# 1000:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 3.371645, acc: 0.125000]
# Saving weights at epoch 1000
# Saving weights at epoch 1010
# Finished Epoch 1020... Time: 0:00:00.213075
# 1020:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.139449, acc: 1.000000]
# Saving weights at epoch 1020
# Saving weights at epoch 1030
# Finished Epoch 1040... Time: 0:00:00.206298
# 1040:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.292040, acc: 0.906250]
# Saving weights at epoch 1040
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 1050
# Finished Epoch 1060... Time: 0:00:00.214005
# 1060:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 9.642796, acc: 0.125000]
# Saving weights at epoch 1060
# Saving weights at epoch 1070
# Finished Epoch 1080... Time: 0:00:00.211415
# 1080:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000007, acc_gen: 1.000000]  [A loss: 10.470779, acc: 0.000000]
# Saving weights at epoch 1080
# Saving weights at epoch 1090
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1100... Time: 0:00:00.215691
# 1100:0: [D loss_hr: 0.000001, acc_hr: 1.000000, loss_gen: 0.000007, acc_gen: 1.000000]  [A loss: 10.266697, acc: 0.000000]
# Saving weights at epoch 1100
# Saving weights at epoch 1110
# Finished Epoch 1120... Time: 0:00:00.222109
# 1120:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000003, acc_gen: 1.000000]  [A loss: 10.216150, acc: 0.000000]
# Saving weights at epoch 1120
# Saving weights at epoch 1130
# Finished Epoch 1140... Time: 0:00:00.220686
# 1140:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000015, acc_gen: 1.000000]  [A loss: 9.314911, acc: 0.000000]
# Saving weights at epoch 1140
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 1150
# Finished Epoch 1160... Time: 0:00:00.220231
# 1160:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.838758, acc: 0.000000]
# Saving weights at epoch 1160
# Saving weights at epoch 1170
# Finished Epoch 1180... Time: 0:00:00.214966
# 1180:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 9.259901, acc: 0.000000]
# Saving weights at epoch 1180
# Saving weights at epoch 1190
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1200... Time: 0:00:00.208092
# 1200:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.985019, acc: 0.000000]
# Saving weights at epoch 1200
# Saving weights at epoch 1210
# Finished Epoch 1220... Time: 0:00:00.204704
# 1220:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 8.210173, acc: 0.109375]
# Saving weights at epoch 1220
# Saving weights at epoch 1230
# Finished Epoch 1240... Time: 0:00:00.226019
# 1240:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.673213, acc: 0.000000]
# Saving weights at epoch 1240
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 1250
# Finished Epoch 1260... Time: 0:00:00.210729
# 1260:0: [D loss_hr: 0.000001, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 11.016220, acc: 0.000000]
# Saving weights at epoch 1260
# Saving weights at epoch 1270
# Finished Epoch 1280... Time: 0:00:00.228292
# 1280:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 10.695818, acc: 0.000000]
# Saving weights at epoch 1280
# Saving weights at epoch 1290
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1300... Time: 0:00:00.219186
# 1300:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 12.000896, acc: 0.000000]
# Saving weights at epoch 1300
# Saving weights at epoch 1310
# Finished Epoch 1320... Time: 0:00:00.214161
# 1320:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 11.694582, acc: 0.000000]
# Saving weights at epoch 1320
# Saving weights at epoch 1330
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1700... Time: 0:00:00.213369
# 1700:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 13.664334, acc: 0.000000]
# Saving weights at epoch 1700
# Saving weights at epoch 1710
# Finished Epoch 1720... Time: 0:00:00.216436
# 1720:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 14.472517, acc: 0.000000]
# Saving weights at epoch 1720
# Saving weights at epoch 1730
# Finished Epoch 1740... Time: 0:00:00.215043
# 1740:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 14.137765, acc: 0.000000]
# Saving weights at epoch 1740
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 1750
# Finished Epoch 1760... Time: 0:00:00.216678
# 1760:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 14.202611, acc: 0.000000]
# Saving weights at epoch 1760
# Saving weights at epoch 1770
# Finished Epoch 1780... Time: 0:00:00.234472
# 1780:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 14.478971, acc: 0.000000]
# Saving weights at epoch 1780
# Saving weights at epoch 1790
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1800... Time: 0:00:00.213647
# 1800:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1800
# Saving weights at epoch 1810
# Finished Epoch 1820... Time: 0:00:00.212879
# 1820:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1820
# Saving weights at epoch 1830
# Finished Epoch 1840... Time: 0:00:00.207213
# 1840:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1840
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 1850
# Finished Epoch 1860... Time: 0:00:00.208520
# 1860:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1860
# Saving weights at epoch 1870
# Finished Epoch 1880... Time: 0:00:00.215775
# 1880:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1880
# Saving weights at epoch 1890
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 1900... Time: 0:00:00.215857
# 1900:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1900
# Saving weights at epoch 1910
# Finished Epoch 1920... Time: 0:00:00.215517
# 1920:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1920
# Saving weights at epoch 1930
# Finished Epoch 1940... Time: 0:00:00.213855
# 1940:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1940
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 1950
# Finished Epoch 1960... Time: 0:00:00.217219
# 1960:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1960
# Saving weights at epoch 1970
# Finished Epoch 1980... Time: 0:00:00.217195
# 1980:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 1980
# Saving weights at epoch 1990
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2000... Time: 0:00:00.215193
# 2000:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2000
# Saving weights at epoch 2010
# Finished Epoch 2020... Time: 0:00:00.209324
# 2020:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2020
# Saving weights at epoch 2030
# Finished Epoch 2040... Time: 0:00:00.208682
# 2040:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2040
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2050
# Finished Epoch 2060... Time: 0:00:00.206936
# 2060:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2060
# Saving weights at epoch 2070
# Finished Epoch 2080... Time: 0:00:00.207403
# 2080:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2080
# Saving weights at epoch 2090
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2100... Time: 0:00:00.214044
# 2100:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2100
# Saving weights at epoch 2110
# Finished Epoch 2120... Time: 0:00:00.227479
# 2120:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2120
# Saving weights at epoch 2130
# Finished Epoch 2140... Time: 0:00:00.211424
# 2140:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2140
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2150
# Finished Epoch 2160... Time: 0:00:00.230037
# 2160:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2160
# Saving weights at epoch 2170
# Finished Epoch 2180... Time: 0:00:00.217053
# 2180:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2180
# Saving weights at epoch 2190
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2200... Time: 0:00:00.220088
# 2200:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2200
# Saving weights at epoch 2210
# Finished Epoch 2220... Time: 0:00:00.227038
# 2220:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2220
# Saving weights at epoch 2230
# Finished Epoch 2240... Time: 0:00:00.210759
# 2240:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2240
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2250
# Finished Epoch 2260... Time: 0:00:00.209709
# 2260:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2260
# Saving weights at epoch 2270
# Finished Epoch 2280... Time: 0:00:00.216108
# 2280:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2280
# Saving weights at epoch 2290
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2300... Time: 0:00:00.216018
# 2300:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2300
# Saving weights at epoch 2310
# Finished Epoch 2320... Time: 0:00:00.217585
# 2320:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2320
# Saving weights at epoch 2330
# Finished Epoch 2340... Time: 0:00:00.224057
# 2340:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2340
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2350
# Finished Epoch 2360... Time: 0:00:00.210735
# 2360:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2360
# Saving weights at epoch 2370
# Finished Epoch 2380... Time: 0:00:00.215516
# 2380:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2380
# Saving weights at epoch 2390
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2400... Time: 0:00:00.209018
# 2400:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2400
# Saving weights at epoch 2410
# Finished Epoch 2420... Time: 0:00:00.217620
# 2420:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2420
# Saving weights at epoch 2430
# Finished Epoch 2440... Time: 0:00:00.225450
# 2440:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2440
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2450
# Finished Epoch 2460... Time: 0:00:00.239960
# 2460:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2460
# Saving weights at epoch 2470
# Finished Epoch 2480... Time: 0:00:00.211988
# 2480:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2480
# Saving weights at epoch 2490
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2500... Time: 0:00:00.213109
# 2500:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2500
# Saving weights at epoch 2510
# Finished Epoch 2520... Time: 0:00:00.210453
# 2520:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2520
# Saving weights at epoch 2530
# Finished Epoch 2540... Time: 0:00:00.206662
# 2540:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2540
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2550
# Finished Epoch 2560... Time: 0:00:00.215385
# 2560:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2560
# Saving weights at epoch 2570
# Finished Epoch 2580... Time: 0:00:00.210157
# 2580:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2580
# Saving weights at epoch 2590
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2600... Time: 0:00:00.214614
# 2600:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2600
# Saving weights at epoch 2610
# Finished Epoch 2620... Time: 0:00:00.216752
# 2620:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2620
# Saving weights at epoch 2630
# Finished Epoch 2640... Time: 0:00:00.218271
# 2640:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2640
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2650
# Finished Epoch 2660... Time: 0:00:00.218882
# 2660:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2660
# Saving weights at epoch 2670
# Finished Epoch 2680... Time: 0:00:00.214332
# 2680:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2680
# Saving weights at epoch 2690
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2700... Time: 0:00:00.220963
# 2700:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2700
# Saving weights at epoch 2710
# Finished Epoch 2720... Time: 0:00:00.218401
# 2720:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2720
# Saving weights at epoch 2730
# Finished Epoch 2740... Time: 0:00:00.211185
# 2740:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2740
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2750
# Finished Epoch 2760... Time: 0:00:00.232121
# 2760:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2760
# Saving weights at epoch 2770
# Finished Epoch 2780... Time: 0:00:00.237297
# 2780:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2780
# Saving weights at epoch 2790
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2800... Time: 0:00:00.211615
# 2800:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2800
# Saving weights at epoch 2810
# Finished Epoch 2820... Time: 0:00:00.224247
# 2820:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2820
# Saving weights at epoch 2830
# Finished Epoch 2840... Time: 0:00:00.210511
# 2840:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2840
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2850
# Finished Epoch 2860... Time: 0:00:00.214684
# 2860:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2860
# Saving weights at epoch 2870
# Finished Epoch 2880... Time: 0:00:00.218234
# 2880:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2880
# Saving weights at epoch 2890
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 2900... Time: 0:00:00.234418
# 2900:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2900
# Saving weights at epoch 2910
# Finished Epoch 2920... Time: 0:00:00.217385
# 2920:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2920
# Saving weights at epoch 2930
# Finished Epoch 2940... Time: 0:00:00.212921
# 2940:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2940
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving weights at epoch 2950
# Finished Epoch 2960... Time: 0:00:00.215220
# 2960:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2960
# Saving weights at epoch 2970
# Finished Epoch 2980... Time: 0:00:00.214105
# 2980:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 2980
# Saving weights at epoch 2990

# %%
self.disc.save(dir_pfx + 'weights/discriminator_weights.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-7750fd96f07a> in <module>
# ----> 1 self.disc.save(dir_pfx + 'weights/discriminator_weights.h5')
#
# NameError: name 'self' is not defined

# %%
np.min(im_lr[ix:ix+1,:,:,:])
# Out:
# -0.36470588235294116

# %%
# 1117, 
ix = 10
ix2 = 11

img = gan.gen.predict(im_lr[ix:ix+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)

img = gan.gen.predict(im_lr[ix2:ix2+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix2,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
floss = []
tloss = []

for i in np.random.randint(low=0,high=len(im_lr),size=(500)):
  tloss.append(gan.disc.predict(im_hr[i:i+1,:,:,:]).squeeze())
  floss.append(gan.disc.predict(gan.gen.predict(im_lr[i:i+1,:,:,:])).squeeze())

  
print('Mean Loss Real Images: {0}'.format(np.mean(tloss)))
print('Mean Loss False Images: {0}'.format(np.mean(floss)))


plt.figure()
plt.plot(list(range(len(tloss))),tloss)
plt.plot(list(range(len(floss))),floss)
plt.legend(['Loss Real Images','Loss Generated Images'])
plt.xlabel('Random Sample Number')
plt.ylabel('Cross Entropy Loss')
plt.show
# Out:
# Mean Loss Real Images: 0.4030747711658478
# Mean Loss False Images: 0.4107280969619751
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-d2ec81538687> in <module>
#      12
#      13 plt.figure()
# ---> 14 plt.plot(list(range(len(tloss))),tloss)
#      15 plt.plot(list(range(len(floss))),floss)
#      16 plt.legend(['Loss Real Images','Loss Generated Images'])
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
# --> 234                              "shapes {} and {}".format(x.shape, y.shape))
#     235
#     236         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (500,) and (500, 4, 4)

# %%
len(floss)
# Out:
# 1000
