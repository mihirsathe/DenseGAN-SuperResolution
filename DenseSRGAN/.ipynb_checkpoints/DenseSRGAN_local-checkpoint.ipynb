# %%
# Local paths
dir_pfx = './'
data_dir = dir_pfx + '../../data/Vehicules1024/'
# Add the local_modules directory to the set of paths
# Python uses to look for imports.
import sys
sys.path.append(dir_pfx)
sys.path.append('../')

# %%
#!pip3 install -q git+https://www.github.com/keras-team/keras-contrib.git
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from importlib import reload
import utils
# Out:
# Using TensorFlow backend.

# %%
reload(utils)
# Out:
# <module 'utils' from '../utils.py'>

# %%
num_images = 3
files = utils.scan_dataset(data_dir, num_images) #TODO: 50
training_set, testing_set = utils.create_subsets(files, data_dir, use_validation=False)
im_hr, im_lr, batch_idx = utils.load_data(0, training_set, data_dir, False, len(training_set))
# Out:
# Using 3 images.
# Saving files to ./../../data/Vehicules1024/

# %%
np.min(im_hr[ix,:,:,:])
# Out:
# 52.0

# %%
ix = 10
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(utils.un_normalize(im_hr[ix,:,:,:]))
plt.subplot(1,2,2)
plt.imshow(utils.un_normalize(im_lr[ix,:,:,:]))

plt.figure().suptitle('RGB', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(utils.un_normalize(im_hr[ix,:,:,0:3]))
plt.subplot(1,2,2)
plt.imshow(utils.un_normalize(im_lr[ix,:,:,0:3]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Prototype the Dense SR GAN
#from importlib import reload
reload(DenseSRGAN)
# Out:
# <module 'DenseSRGAN' from '/home/jupyter/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py'>

# %%
import DenseSRGAN
gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr[0:17,:,:,:],im_lr[0:17,:,:,:],num_gpus=[4,5,6,7],dropout_rate=0.5)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=4,dropout_rate=0.3,weights_path='weights/')

# %%
#gan.dropout_rate = .5
gan.train(epochs=1000,verbose=False,bench_idx=3,batch_size=4,save_interval=50,view_interval=20)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Finished Epoch 0... Time: 0:00:43.244618
# 0:0: [D loss_hr: 0.332694, acc_hr: 0.375000, loss_gen: 0.334153, acc_gen: 0.375000]  [A loss: 0.722671, acc: 0.562500]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 0
# Epoch: 10
# Finished Epoch 20... Time: 0:00:00.210185
# 20:0: [D loss_hr: 0.001444, acc_hr: 1.000000, loss_gen: 0.002946, acc_gen: 1.000000]  [A loss: 0.172367, acc: 0.984375]
# Epoch: 20
# Epoch: 30
# Finished Epoch 40... Time: 0:00:00.197074
# 40:0: [D loss_hr: 0.000317, acc_hr: 1.000000, loss_gen: 0.000345, acc_gen: 1.000000]  [A loss: 0.080535, acc: 1.000000]
# Epoch: 40
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 50
# Finished Epoch 60... Time: 0:00:00.203136
# 60:0: [D loss_hr: 0.000038, acc_hr: 1.000000, loss_gen: 0.000040, acc_gen: 1.000000]  [A loss: 0.054306, acc: 1.000000]
# Epoch: 60
# Epoch: 70
# Finished Epoch 80... Time: 0:00:00.192574
# 80:0: [D loss_hr: 0.000005, acc_hr: 1.000000, loss_gen: 0.000005, acc_gen: 1.000000]  [A loss: 0.027768, acc: 1.000000]
# Epoch: 80
# Epoch: 90
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 100... Time: 0:00:00.202837
# 100:0: [D loss_hr: 0.000001, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 0.023156, acc: 1.000000]
# Epoch: 100
# Epoch: 110
# Finished Epoch 120... Time: 0:00:00.198757
# 120:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.026008, acc: 1.000000]
# Epoch: 120
# Epoch: 130
# Finished Epoch 140... Time: 0:00:00.201850
# 140:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.015501, acc: 1.000000]
# Epoch: 140
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 150
# Finished Epoch 160... Time: 0:00:00.211049
# 160:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.076553, acc: 0.984375]
# Epoch: 160
# Epoch: 170
# Finished Epoch 180... Time: 0:00:00.196220
# 180:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.010561, acc: 1.000000]
# Epoch: 180
# Epoch: 190
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 200... Time: 0:00:00.210215
# 200:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.003974, acc: 1.000000]
# Epoch: 200
# Epoch: 210
# Finished Epoch 220... Time: 0:00:00.226267
# 220:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.004150, acc: 1.000000]
# Epoch: 220
# Epoch: 230
# Finished Epoch 240... Time: 0:00:00.195536
# 240:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.018085, acc: 0.984375]
# Epoch: 240
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 250
# Finished Epoch 260... Time: 0:00:00.199603
# 260:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.002637, acc: 1.000000]
# Epoch: 260
# Epoch: 270
# Finished Epoch 280... Time: 0:00:00.201202
# 280:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.003467, acc: 1.000000]
# Epoch: 280
# Epoch: 290
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 300... Time: 0:00:00.202896
# 300:0: [D loss_hr: 0.000001, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.008217, acc: 1.000000]
# Epoch: 300
# Epoch: 310
# Finished Epoch 320... Time: 0:00:00.207836
# 320:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.002553, acc: 1.000000]
# Epoch: 320
# Epoch: 330
# Finished Epoch 340... Time: 0:00:00.208946
# 340:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.002069, acc: 1.000000]
# Epoch: 340
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 350
# Finished Epoch 360... Time: 0:00:00.208793
# 360:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.001528, acc: 1.000000]
# Epoch: 360
# Epoch: 370
# Finished Epoch 380... Time: 0:00:00.194759
# 380:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.001751, acc: 1.000000]
# Epoch: 380
# Epoch: 390
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 400... Time: 0:00:00.212840
# 400:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.001473, acc: 1.000000]
# Epoch: 400
# Epoch: 410
# Finished Epoch 420... Time: 0:00:00.196644
# 420:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000345, acc: 1.000000]
# Epoch: 420
# Epoch: 430
# Finished Epoch 440... Time: 0:00:00.204089
# 440:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000513, acc: 1.000000]
# Epoch: 440
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 450
# Finished Epoch 460... Time: 0:00:00.204790
# 460:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000281, acc: 1.000000]
# Epoch: 460
# Epoch: 470
# Finished Epoch 480... Time: 0:00:00.201975
# 480:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000435, acc: 1.000000]
# Epoch: 480
# Epoch: 490
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 500... Time: 0:00:00.208520
# 500:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000436, acc: 1.000000]
# Epoch: 500
# Epoch: 510
# Finished Epoch 520... Time: 0:00:00.201386
# 520:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000479, acc: 1.000000]
# Epoch: 520
# Epoch: 530
# Finished Epoch 540... Time: 0:00:00.202471
# 540:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000462, acc: 1.000000]
# Epoch: 540
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 550
# Finished Epoch 560... Time: 0:00:00.198955
# 560:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000308, acc: 1.000000]
# Epoch: 560
# Epoch: 570
# Finished Epoch 580... Time: 0:00:00.205685
# 580:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000257, acc: 1.000000]
# Epoch: 580
# Epoch: 590
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 600... Time: 0:00:00.197389
# 600:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000257, acc: 1.000000]
# Epoch: 600
# Epoch: 610
# Finished Epoch 620... Time: 0:00:00.205440
# 620:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000001, acc_gen: 1.000000]  [A loss: 0.328386, acc: 0.875000]
# Epoch: 620
# Epoch: 630
# Finished Epoch 640... Time: 0:00:00.205743
# 640:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000533, acc: 1.000000]
# Epoch: 640
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 650
# Finished Epoch 660... Time: 0:00:00.196818
# 660:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000141, acc: 1.000000]
# Epoch: 660
# Epoch: 670
# Finished Epoch 680... Time: 0:00:00.204194
# 680:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000046, acc: 1.000000]
# Epoch: 680
# Epoch: 690
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 700... Time: 0:00:00.194263
# 700:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000046, acc: 1.000000]
# Epoch: 700
# Epoch: 710
# Finished Epoch 720... Time: 0:00:00.206018
# 720:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000026, acc: 1.000000]
# Epoch: 720
# Epoch: 730
# Finished Epoch 740... Time: 0:00:00.183524
# 740:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000038, acc: 1.000000]
# Epoch: 740
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 750
# Finished Epoch 760... Time: 0:00:00.192579
# 760:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000038, acc: 1.000000]
# Epoch: 760
# Epoch: 770
# Finished Epoch 780... Time: 0:00:00.183913
# 780:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000027, acc: 1.000000]
# Epoch: 780
# Epoch: 790
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 800... Time: 0:00:00.195007
# 800:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000013, acc: 1.000000]
# Epoch: 800
# Epoch: 810
# Finished Epoch 820... Time: 0:00:00.202866
# 820:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000013, acc: 1.000000]
# Epoch: 820
# Epoch: 830
# Finished Epoch 840... Time: 0:00:00.191749
# 840:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000053, acc: 1.000000]
# Epoch: 840
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 850
# Finished Epoch 860... Time: 0:00:00.184703
# 860:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000026, acc: 1.000000]
# Epoch: 860
# Epoch: 870
# Finished Epoch 880... Time: 0:00:00.209091
# 880:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000015, acc: 1.000000]
# Epoch: 880
# Epoch: 890
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished Epoch 900... Time: 0:00:00.207311
# 900:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000011, acc: 1.000000]
# Epoch: 900
# Epoch: 910
# Finished Epoch 920... Time: 0:00:00.206083
# 920:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000014, acc: 1.000000]
# Epoch: 920
# Epoch: 930
# Finished Epoch 940... Time: 0:00:00.202617
# 940:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000010, acc: 1.000000]
# Epoch: 940
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 950
# Finished Epoch 960... Time: 0:00:00.219796
# 960:0: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000015, acc: 1.000000]
# Epoch: 960
# Epoch: 970
# Finished Epoch 980... Time: 0:00:00.205470
# 980:0: [D loss_hr: 0.000027, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 5.268415, acc: 0.156250]
# Epoch: 980
# Epoch: 990

# %%
self.disc.save(dir_pfx + 'weights/discriminator_weights.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-7750fd96f07a> in <module>
# ----> 1 self.disc.save(dir_pfx + 'weights/discriminator_weights.h5')
#
# NameError: name 'self' is not defined

# %%
np.min(im_lr[ix:ix+1,:,:,:])
# Out:
# -0.36470588235294116

# %%
# 1117, 
ix = 10
ix2 = 11

img = gan.gen.predict(im_lr[ix:ix+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)

img = gan.gen.predict(im_lr[ix2:ix2+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix2,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
floss = []
tloss = []

for i in np.random.randint(low=0,high=len(im_lr),size=(1000)):
  tloss.append(gan.disc.predict(im_hr[i:i+1,:,:,:]).squeeze())
  floss.append(gan.disc.predict(gan.gen.predict(im_lr[i:i+1,:,:,:])).squeeze())

  
print('Mean Loss Real Images: {0}'.format(np.mean(tloss)))
print('Mean Loss False Images: {0}'.format(np.mean(floss)))


plt.figure()
plt.plot(list(range(len(tloss))),tloss)
plt.plot(list(range(len(floss))),floss)
plt.legend(['Loss Real Images','Loss Generated Images'])
plt.xlabel('Random Sample Number')
plt.ylabel('Cross Entropy Loss')
plt.show
# Out:
# Mean Loss Real Images: 0.5230975151062012
# Mean Loss False Images: 0.5427525639533997
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-2cd42fcae2ed> in <module>
#      12
#      13 plt.figure()
# ---> 14 plt.plot(list(range(len(tloss))),tloss)
#      15 plt.plot(list(range(len(floss))),floss)
#      16 plt.legend(['Loss Real Images','Loss Generated Images'])
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
# --> 234                              "shapes {} and {}".format(x.shape, y.shape))
#     235
#     236         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (1000,) and (1000, 4, 4)

# %%
len(floss)
# Out:
# 1000
