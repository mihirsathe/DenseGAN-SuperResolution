# %%
# Local paths
dir_pfx = './'
data_dir = dir_pfx + '../../data/Vehicules1024/'
# Add the local_modules directory to the set of paths
# Python uses to look for imports.
import sys
sys.path.append(dir_pfx)
sys.path.append('../')

# %%
#!pip3 install -q git+https://www.github.com/keras-team/keras-contrib.git
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from importlib import reload
import utils
# Out:
# Using TensorFlow backend.

# %%
num_images = 50
files = utils.scan_dataset(data_dir, num_images) #TODO: 50
training_set, testing_set = utils.create_subsets(files, data_dir, use_validation=False)
im_hr, im_lr, batch_idx = utils.load_data(0, training_set, data_dir, True, len(training_set))
# Out:
# The following image is missing!: 00000005
# The following image is missing!: 00000023
# Using 48 images.
# Saving files to ./../../data/Vehicules1024/

# %%
ix = 2560
normalized_around_zero = False

if normalized_around_zero:
    plt.figure().suptitle('RGB+Infra', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(utils.un_normalize(im_hr[ix,:,:,:]))
    plt.subplot(1,2,2)
    plt.imshow(utils.un_normalize(im_lr[ix,:,:,:]))

    plt.figure().suptitle('RGB', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(utils.un_normalize(im_hr[ix,:,:,0:3]))
    plt.subplot(1,2,2)
    plt.imshow(utils.un_normalize(im_lr[ix,:,:,0:3]))
else:
    plt.figure().suptitle('RGB+Infra', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(im_hr[ix,:,:,:])
    plt.subplot(1,2,2)
    plt.imshow(im_lr[ix,:,:,:])

    plt.figure().suptitle('RGB', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(im_hr[ix,:,:,0:3])
    plt.subplot(1,2,2)
    plt.imshow(im_lr[ix,:,:,0:3])

# %%
# Prototype the Dense SR GAN
#from importlib import reload
reload(DenseSRGAN)
# Out:
# <module 'DenseSRGAN' from '/home/jupyter/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py'>

# %%
import DenseSRGAN
# Start
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="OH",gpu_list=[5,7],dropout_rate=0.3)
# Continue
gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="OH",gpu_list=[1,3,5,7],dropout_rate=0.3,num_epochs_trained=450,weights_path='./weights/OH/')

# Start
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="OH",dropout_rate=0.3)
# Continue
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="OH",dropout_rate=0.3,num_epochs_trained=500,weights_path='./weights/OH/')

#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr[0:17,:,:,:],im_lr[0:17,:,:,:],dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=[6],dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=4,dropout_rate=0.3,weights_path='weights/')

# %%
#gan.dropout_rate = .5 benchidx = 2000
gan.train(epochs=1000,verbose=False,bench_idx=2560,batch_size=16,save_interval=10,view_interval=2)
# Out:
# Finished Epoch 460... Time: 0:01:16.857251
# 460:263: [D loss_hr: 0.004851, acc_hr: 0.992188, loss_gen: 0.000062, acc_gen: 1.000000]  [A loss: 0.028915, acc: 0.992188]
# Saving weights at epoch 460
# Finished Epoch 462... Time: 0:01:16.175734
# 462:263: [D loss_hr: 0.000002, acc_hr: 1.000000, loss_gen: 0.000006, acc_gen: 1.000000]  [A loss: 0.002064, acc: 1.000000]
# Finished Epoch 464... Time: 0:01:16.151871
# 464:263: [D loss_hr: 0.009700, acc_hr: 0.988281, loss_gen: 0.000100, acc_gen: 1.000000]  [A loss: 0.000963, acc: 1.000000]
# Finished Epoch 466... Time: 0:01:16.172426
# 466:263: [D loss_hr: 0.008496, acc_hr: 0.984375, loss_gen: 0.000059, acc_gen: 1.000000]  [A loss: 0.015250, acc: 0.996094]
# Finished Epoch 468... Time: 0:01:16.166474
# 468:263: [D loss_hr: 0.000004, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.002025, acc: 1.000000]
# Finished Epoch 470... Time: 0:01:16.058414
# 470:263: [D loss_hr: 0.000001, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000074, acc: 1.000000]
# Saving weights at epoch 470
# Finished Epoch 472... Time: 0:01:15.423429
# 472:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000004, acc: 1.000000]
# Finished Epoch 474... Time: 0:01:16.310491
# 474:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000417, acc: 1.000000]
# Finished Epoch 476... Time: 0:01:16.136493
# 476:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000004, acc: 1.000000]
# Finished Epoch 478... Time: 0:01:15.711600
# 478:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000017, acc: 1.000000]
# Finished Epoch 480... Time: 0:01:15.939504
# 480:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000008, acc: 1.000000]
# Saving weights at epoch 480
# Finished Epoch 482... Time: 0:01:15.639051
# 482:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.005805, acc: 1.000000]
# Finished Epoch 484... Time: 0:01:16.204334
# 484:263: [D loss_hr: 0.000021, acc_hr: 1.000000, loss_gen: 0.000008, acc_gen: 1.000000]  [A loss: 9.610597, acc: 0.000000]
# Finished Epoch 486... Time: 0:01:15.762911
# 486:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 488... Time: 0:01:16.070003
# 488:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 490... Time: 0:01:15.996982
# 490:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 490
# Finished Epoch 492... Time: 0:01:15.418196
# 492:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 494... Time: 0:01:16.117636
# 494:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 496... Time: 0:01:15.984107
# 496:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 498... Time: 0:01:15.969791
# 498:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 500... Time: 0:01:16.240579
# 500:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Saving weights at epoch 500
# Finished Epoch 502... Time: 0:01:16.090656
# 502:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# Finished Epoch 504... Time: 0:01:15.409819
# 504:263: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 16.118095, acc: 0.000000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-bf1b123b45ad> in <module>
#       1 #gan.dropout_rate = .5 benchidx = 2000
# ----> 2 gan.train(epochs=1000,verbose=False,bench_idx=2560,batch_size=16,save_interval=10,view_interval=2)
#
# ~/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py in train(self, datahr, datalr, epochs, batch_size, callbacks, save_interval, view_interval, bench_idx, verbose)
#     353             # Train the discriminator alone
#     354             d_loss_hr  = self.disc_model.train_on_batch(x_tr, y_tr)
# --> 355             d_loss_gen = self.disc_model.train_on_batch(x_gen, y_gen)
#     356             if verbose: print('Done training. Time: {0}'.format(datetime.datetime.now() - ti))
#     357
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#self.disc.save(dir_pfx + 'weights/discriminator_weights.h5')

# %%
np.min(im_lr[ix:ix+1,:,:,:])

# %%
# 1117, 
ix = 10
ix2 = 11

img = gan.gen.predict(im_lr[ix:ix+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)

img = gan.gen.predict(im_lr[ix2:ix2+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix2,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)

# %%
floss = []
tloss = []

for i in np.random.randint(low=0,high=len(im_lr),size=(500)):
  tloss.append(gan.disc.predict(im_hr[i:i+1,:,:,:]).squeeze())
  floss.append(gan.disc.predict(gan.gen.predict(im_lr[i:i+1,:,:,:])).squeeze())

  
print('Mean Loss Real Images: {0}'.format(np.mean(tloss)))
print('Mean Loss False Images: {0}'.format(np.mean(floss)))


plt.figure()
plt.plot(list(range(len(tloss))),tloss)
plt.plot(list(range(len(floss))),floss)
plt.legend(['Loss Real Images','Loss Generated Images'])
plt.xlabel('Random Sample Number')
plt.ylabel('Cross Entropy Loss')
plt.show
