# %%
# Local paths
dir_pfx = './'
data_dir = dir_pfx + '../../data/Vehicules1024/'
# Add the local_modules directory to the set of paths
# Python uses to look for imports.
import sys
sys.path.append(dir_pfx)
sys.path.append('../')

# %%
#!pip3 install -q git+https://www.github.com/keras-team/keras-contrib.git
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from importlib import reload
import utils
# Out:
# Using TensorFlow backend.

# %%
#num_images = 3
#files = utils.scan_dataset(data_dir, num_images) #TODO: 50
#training_set, testing_set = utils.create_subsets(files, data_dir, use_validation=False)
#im_hr, im_lr, batch_idx = utils.load_data(0, training_set, data_dir, True, len(training_set))
vehicles_dir = dir_pfx + '../../data/vehicle_patches_64/'
#im_hr, im_lr = utils.load_data_vehicles(vehicles_dir, 1, img_spec=2021)
im_hr, im_lr = utils.load_data_vehicles(vehicles_dir, 3178, scale01=True)
# Out:
# using 3178 images
# 3178

# %%
ix = 12
normalized_around_zero = False

if normalized_around_zero:
    plt.figure().suptitle('RGB+Infra', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(utils.un_normalize(im_hr[ix,:,:,:]))
    plt.subplot(1,2,2)
    plt.imshow(utils.un_normalize(im_lr[ix,:,:,:]))

    plt.figure().suptitle('RGB', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(utils.un_normalize(im_hr[ix,:,:,0:3]))
    plt.subplot(1,2,2)
    plt.imshow(utils.un_normalize(im_lr[ix,:,:,0:3]))
else:
    plt.figure().suptitle('RGB+Infra', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(im_hr[ix,:,:,:])
    plt.subplot(1,2,2)
    plt.imshow(im_lr[ix,:,:,:])

    plt.figure().suptitle('RGB', fontsize=20)
    plt.subplot(1,2,1)
    plt.imshow(im_hr[ix,:,:,0:3])
    plt.subplot(1,2,2)
    plt.imshow(im_lr[ix,:,:,0:3])

# %%
# Prototype the Dense SR GAN
#from importlib import reload
#reload(DenseSRGAN)

# %%
import DenseSRGAN
# Start
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="OH",gpu_list=[5,7],dropout_rate=0.3)
# Continue
gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="VEH",gpu_list=[2,4,6],dropout_rate=0.3,num_epochs_trained=200,weights_path='./weights/VEH/')


# Start
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="OH",dropout_rate=0.3)
# Continue
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,proj_pfx="VEH",dropout_rate=0.3,num_epochs_trained=200,weights_path='./weights/VEH/')


#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr[0:17,:,:,:],im_lr[0:17,:,:,:],dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=[6],dropout_rate=0.3)
#gan = DenseSRGAN.DenseSRGAN(dir_pfx,im_hr,im_lr,num_gpus=4,dropout_rate=0.3,weights_path='weights/')

# %%
#gan.dropout_rate = .5 benchidx = 2000
gan.train(epochs=1000,verbose=False,bench_idx=2000,batch_size=16,save_interval=10,view_interval=5)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Finished Epoch 205... Time: 0:00:25.255770
# 205:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000246, acc: 1.000000]
# Finished Epoch 210... Time: 0:00:26.831055
# 210:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000075, acc: 1.000000]
# Saving weights at epoch 210
# Finished Epoch 215... Time: 0:00:27.101095
# 215:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000030, acc: 1.000000]
# Finished Epoch 220... Time: 0:00:26.675569
# 220:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000010, acc: 1.000000]
# Saving weights at epoch 220
# Finished Epoch 225... Time: 0:00:27.109816
# 225:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000030, acc: 1.000000]
# Finished Epoch 230... Time: 0:00:26.834411
# 230:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000011, acc: 1.000000]
# Saving weights at epoch 230
# Finished Epoch 235... Time: 0:00:26.615247
# 235:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000005, acc: 1.000000]
# Finished Epoch 240... Time: 0:00:25.308219
# 240:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000004, acc: 1.000000]
# Saving weights at epoch 240
# Finished Epoch 245... Time: 0:00:25.307627
# 245:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000005, acc: 1.000000]
# Finished Epoch 250... Time: 0:00:26.874211
# 250:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000002, acc: 1.000000]
# Saving weights at epoch 250
# Finished Epoch 255... Time: 0:00:26.801799
# 255:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000002, acc: 1.000000]
# Finished Epoch 260... Time: 0:00:26.832702
# 260:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000002, acc: 1.000000]
# Saving weights at epoch 260
# Finished Epoch 265... Time: 0:00:26.803577
# 265:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000002, acc: 1.000000]
# Finished Epoch 270... Time: 0:00:26.773545
# 270:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 270
# Finished Epoch 275... Time: 0:00:26.730867
# 275:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 280... Time: 0:00:26.812941
# 280:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 280
# Finished Epoch 285... Time: 0:00:26.731448
# 285:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 290... Time: 0:00:26.795216
# 290:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 290
# Finished Epoch 295... Time: 0:00:26.771006
# 295:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 300... Time: 0:00:26.907133
# 300:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 300
# Finished Epoch 305... Time: 0:00:26.571575
# 305:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 310... Time: 0:00:26.798283
# 310:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 310
# Finished Epoch 315... Time: 0:00:26.792996
# 315:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 320... Time: 0:00:26.789484
# 320:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 320
# Finished Epoch 325... Time: 0:00:26.776045
# 325:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 330... Time: 0:00:26.689195
# 330:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 330
# Finished Epoch 335... Time: 0:00:26.717251
# 335:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 340... Time: 0:00:26.774507
# 340:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 340
# Finished Epoch 345... Time: 0:00:26.621588
# 345:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 350... Time: 0:00:26.740399
# 350:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 350
# Finished Epoch 355... Time: 0:00:26.725971
# 355:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 360... Time: 0:00:26.945730
# 360:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 360
# Finished Epoch 365... Time: 0:00:26.977716
# 365:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Finished Epoch 370... Time: 0:00:26.920072
# 370:97: [D loss_hr: 0.000000, acc_hr: 1.000000, loss_gen: 0.000000, acc_gen: 1.000000]  [A loss: 0.000001, acc: 1.000000]
# Saving weights at epoch 370
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-98275375f456> in <module>
#       1 #gan.dropout_rate = .5 benchidx = 2000
# ----> 2 gan.train(epochs=1000,verbose=False,bench_idx=2000,batch_size=16,save_interval=10,view_interval=5)
#
# ~/ECE285FA18_BestGroup/DenseSRGAN/DenseSRGAN.py in train(self, datahr, datalr, epochs, batch_size, callbacks, save_interval, view_interval, bench_idx, verbose)
#     368             if verbose: print('Training GAN...')
#     369             ti = datetime.datetime.now()
# --> 370             a_loss = self.adv_model.train_on_batch(x_tr, y_tr)
#     371             if verbose: print('Done training GAN. Time: {0}'.format(datetime.datetime.now() - ti))
#     372
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#self.disc.save(dir_pfx + 'weights/discriminator_weights.h5')

# %%
np.min(im_lr[ix:ix+1,:,:,:])

# %%
# 1117, 
ix = 10
ix2 = 11

img = gan.gen.predict(im_lr[ix:ix+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)

img = gan.gen.predict(im_lr[ix2:ix2+1,:,:,:]).squeeze()
img = (img + 1)/2
plt.figure().suptitle('RGB+Infra', fontsize=20)
plt.subplot(1,2,1)
plt.imshow(im_hr[ix2,:,:,:])
plt.subplot(1,2,2)
plt.imshow(img)

# %%
floss = []
tloss = []

for i in np.random.randint(low=0,high=len(im_lr),size=(500)):
  tloss.append(gan.disc.predict(im_hr[i:i+1,:,:,:]).squeeze())
  floss.append(gan.disc.predict(gan.gen.predict(im_lr[i:i+1,:,:,:])).squeeze())

  
print('Mean Loss Real Images: {0}'.format(np.mean(tloss)))
print('Mean Loss False Images: {0}'.format(np.mean(floss)))


plt.figure()
plt.plot(list(range(len(tloss))),tloss)
plt.plot(list(range(len(floss))),floss)
plt.legend(['Loss Real Images','Loss Generated Images'])
plt.xlabel('Random Sample Number')
plt.ylabel('Cross Entropy Loss')
plt.show
